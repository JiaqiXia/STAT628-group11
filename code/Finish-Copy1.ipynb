# %% [markdown]
# # Our group are interested in Fastfood restuarants, we want to give some suggestions to owners of Fastfood restuarants in US based on Yelp review

# %%
import pandas as pd
import ast
import json
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats
sns.set(rc={'figure.figsize':(12,8)})

# %%
df_b = pd.read_json('yelp_dataset_2022/business.json', lines=True)

# %%
df_b
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2                  5255 E Broadway Blvd         Tucson    AZ       85711
# 3                           935 Race St   Philadelphia    PA       19107
# 4                         101 Walnut St     Green Lane    PA       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    AB     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    TN       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    IN       46250
# 150344                     2472 Troy Rd   Edwardsville    IL       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    FL       33572
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       34.426679 -119.711197    5.0             7        0
# 1       38.551126  -90.335695    3.0            15        1
# 2       32.223236 -110.880452    3.5            22        0
# 3       39.955505  -75.155564    4.0            80        1
# 4       40.338183  -75.471659    4.5            13        1
# ...           ...         ...    ...           ...      ...
# 150341  53.468419 -113.492054    3.0            13        1
# 150342  36.115118  -86.766925    4.0             5        1
# 150343  39.908707  -86.065088    3.5             8        1
# 150344  38.782351  -89.950558    4.0            24        1
# 150345  27.771002  -82.394910    4.5             9        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 1                  {'BusinessAcceptsCreditCards': 'True'}
# 2       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# ...                                                   ...
# 150341  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 150342  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150343  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344  {'BusinessParking': '{'garage': False, 'street...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 0                                                    None
# 1       {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2       {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 150341  {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:3...
# 150342  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...
# 150343                                               None
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [150346 rows x 14 columns]

# %% [markdown]
# ## Only keep the businesses that are still open

# %%
df_b = df_b[df_b['is_open']==1]

# %% [markdown]
# ## Only keep states in US

# %%
df_b["state"].value_counts()
us_states = ["AL", "KY", "OH", "AK", "LA", "OK", "AZ", "ME", "OR", "AR", "MD", "PA", "AS",
             "MA", "PR", "CA", "MI", "RI", "CO", "MN", "SC", "CT", "MS", "SD", "DE", "MO",
             "TN", "DC", "MT", "TX", "FL", "NE", "TT", "GA", "NV", "UT", "GU", "NH", "VT",
             "HI", "NJ", "VA","ID", "NM", "VI", "IL", "NY", "WA", "IN", "NC", "WV", "IA", 
             "ND", "WI", "KS", "MP", "WY"]
df_b = df_b[df_b['state'].isin(us_states)]
df_b["state"].value_counts()
# Out:
# PA    26289
# FL    21540
# TN     9600
# IN     8946
# MO     8363
# AZ     8108
# LA     7676
# NJ     7031
# NV     6277
# CA     4065
# ID     3783
# DE     1894
# IL     1765
# TX        4
# WA        2
# MA        2
# HI        1
# UT        1
# CO        1
# MI        1
# SD        1
# VT        1
# Name: state, dtype: int64

# %% [markdown]
# ## Exact rows containig "Fast Food"

# %%
business_list = list(df_b["categories"])

# %%
# show categories
business_set = []
for i in business_list:
    if i:
        business_set.extend(i.split(", "))
pd.Series(business_set).value_counts()[:50]
# Out:
# Restaurants                  33252
# Food                         19498
# Shopping                     19362
# Home Services                13164
# Beauty & Spas                11838
# Health & Medical             10810
# Local Services                9935
# Automotive                    9624
# Nightlife                     8053
# Event Planning & Services     7989
# Bars                          7242
# Active Life                   6283
# Sandwiches                    5894
# American (Traditional)        5393
# Fast Food                     5241
# Hotels & Travel               5019
# Home & Garden                 4877
# Auto Repair                   4876
# Pizza                         4847
# Coffee & Tea                  4688
# Breakfast & Brunch            4245
# Arts & Entertainment          4209
# Fashion                       4182
# Burgers                       4091
# Hair Salons                   4037
# Nail Salons                   3911
# American (New)                3566
# Doctors                       3517
# Mexican                       3274
# Pets                          3258
# Real Estate                   3139
# Professional Services         2986
# Specialty Food                2945
# Italian                       2827
# Hair Removal                  2760
# Fitness & Instruction         2556
# Grocery                       2519
# Hotels                        2478
# Seafood                       2419
# Dentists                      2399
# Pet Services                  2311
# Chicken Wings                 2269
# Salad                         2213
# Contractors                   2205
# Tires                         2191
# Chinese                       2149
# Oil Change Stations           2103
# Desserts                      2100
# Bakeries                      2082
# Skin Care                     2077
# dtype: int64

# %%
fastfood = df_b[df_b.categories.str.contains('Fast Food',case=True,na=False)]
fastfood
# Out:
#                    business_id                        name  \
# 5       CF33F8-E6oudUQ46HnavjQ              Sonic Drive-In
# 9       bBDDEgkFA1Otx9Lfe7BZUQ              Sonic Drive-In
# 97      knQ4vIgx-r85kjlWVVjcpQ  Silver and Blue Outfitters
# 122     VZzivJEbmHItOxNXJB3SpA                      Subway
# 153     aNtKyc2rr-uK5cqzY9TVQQ      Chipotle Mexican Grill
# ...                        ...                         ...
# 150183  _rM0QpGDdFk3Vux2kltQsQ                     Wendy's
# 150193  0COlL5IKRu5sdWIsEiQAZg                 Chick-fil-A
# 150205  Agh0Z_PACmbdEpLyjvuwZg                 Chick-fil-A
# 150231  C96ynw3G1KrqBOdafxbTKw                      Subway
# 150313  sf_oQ62L8UEnOOLf00nNGA                   Pizza Hut
#
#                            address             city state postal_code  \
# 5                    615 S Main St     Ashland City    TN       37015
# 9              2312 Dickerson Pike        Nashville    TN       37207
# 97         5191 Meadowood Mall Cir             Reno    NV       89502
# 122     330 Franklin Rd, Ste 900-d        Brentwood    TN       37027
# 153              10160 Ulmerton Rd            Largo    FL       33771
# ...                            ...              ...   ...         ...
# 150183    8009 West Florissant Ave         St.Louis    MO       63136
# 150193            20 State Farm Dr       Glen Mills    PA       19342
# 150205      6240 E Whitestown Pkwy       Whitestown    IN       46075
# 150231   4882 Sun City Center Blvd  Sun City Center    FL       33573
# 150313            5028 Old Hickory        Hermitage    TN       37076
#
#          latitude   longitude  stars  review_count  is_open  \
# 5       36.269593  -87.058943    2.0             6        1
# 9       36.208102  -86.768170    1.5            10        1
# 97      39.476518 -119.784037    4.5             5        1
# 122     36.026363  -86.789473    2.5            14        1
# 153     27.894167  -82.779866    3.0            19        1
# ...           ...         ...    ...           ...      ...
# 150183  38.727495  -90.276069    2.5             5        1
# 150193  39.883115  -75.542323    3.0            52        1
# 150205  39.949502  -86.349949    2.5            32        1
# 150231  27.714605  -82.335851    4.0             5        1
# 150313  36.193201  -86.614748    3.0             6        1
#
#                                                attributes  \
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 9       {'RestaurantsAttire': ''casual'', 'Restaurants...
# 97      {'BikeParking': 'True', 'WiFi': 'u'no'', 'Dogs...
# 122     {'BusinessParking': '{'garage': False, 'street...
# 153     {'RestaurantsPriceRange2': '1', 'Caters': 'Tru...
# ...                                                   ...
# 150183  {'RestaurantsReservations': 'False', 'Business...
# 150193  {'BusinessParking': '{'garage': False, 'street...
# 150205  {'BusinessParking': '{'garage': False, 'street...
# 150231  {'GoodForKids': 'True', 'RestaurantsTakeOut': ...
# 150313  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...
#
#                                                categories  \
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 97      Sporting Goods, Sports Wear, Fashion, Restaura...
# 122                    Sandwiches, Fast Food, Restaurants
# 153                       Mexican, Fast Food, Restaurants
# ...                                                   ...
# 150183        Burgers, Restaurants, Fast Food, Sandwiches
# 150193  Caterers, Fast Food, Event Planning & Services...
# 150205  Chicken Shop, Caterers, Fast Food, Restaurants...
# 150231                 Restaurants, Fast Food, Sandwiches
# 150313  Restaurants, Pizza, Fast Food, Chicken Wings, ...
#
#                                                     hours
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 97      {'Monday': '0:0-0:0', 'Tuesday': '10:0-21:0', ...
# 122     {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 153     {'Monday': '0:0-0:0', 'Tuesday': '10:45-22:0',...
# ...                                                   ...
# 150183  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...
# 150193  {'Monday': '0:0-0:0', 'Tuesday': '10:30-21:0',...
# 150205  {'Monday': '0:0-0:0', 'Tuesday': '6:30-21:0', ...
# 150231  {'Monday': '0:0-0:0', 'Tuesday': '9:0-21:0', '...
# 150313  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
#
# [5241 rows x 14 columns]

# %% [markdown]
# ### remove rows that have no attributes(attributes == "NA")

# %%
fastfood = fastfood.loc[~(pd.isna(fastfood["attributes"])), :] 
fastfood = fastfood.loc[~(pd.isna(fastfood["stars"])), :]

# %%
fastfood
# Out:
#                    business_id                        name  \
# 5       CF33F8-E6oudUQ46HnavjQ              Sonic Drive-In
# 9       bBDDEgkFA1Otx9Lfe7BZUQ              Sonic Drive-In
# 97      knQ4vIgx-r85kjlWVVjcpQ  Silver and Blue Outfitters
# 122     VZzivJEbmHItOxNXJB3SpA                      Subway
# 153     aNtKyc2rr-uK5cqzY9TVQQ      Chipotle Mexican Grill
# ...                        ...                         ...
# 150183  _rM0QpGDdFk3Vux2kltQsQ                     Wendy's
# 150193  0COlL5IKRu5sdWIsEiQAZg                 Chick-fil-A
# 150205  Agh0Z_PACmbdEpLyjvuwZg                 Chick-fil-A
# 150231  C96ynw3G1KrqBOdafxbTKw                      Subway
# 150313  sf_oQ62L8UEnOOLf00nNGA                   Pizza Hut
#
#                            address             city state postal_code  \
# 5                    615 S Main St     Ashland City    TN       37015
# 9              2312 Dickerson Pike        Nashville    TN       37207
# 97         5191 Meadowood Mall Cir             Reno    NV       89502
# 122     330 Franklin Rd, Ste 900-d        Brentwood    TN       37027
# 153              10160 Ulmerton Rd            Largo    FL       33771
# ...                            ...              ...   ...         ...
# 150183    8009 West Florissant Ave         St.Louis    MO       63136
# 150193            20 State Farm Dr       Glen Mills    PA       19342
# 150205      6240 E Whitestown Pkwy       Whitestown    IN       46075
# 150231   4882 Sun City Center Blvd  Sun City Center    FL       33573
# 150313            5028 Old Hickory        Hermitage    TN       37076
#
#          latitude   longitude  stars  review_count  is_open  \
# 5       36.269593  -87.058943    2.0             6        1
# 9       36.208102  -86.768170    1.5            10        1
# 97      39.476518 -119.784037    4.5             5        1
# 122     36.026363  -86.789473    2.5            14        1
# 153     27.894167  -82.779866    3.0            19        1
# ...           ...         ...    ...           ...      ...
# 150183  38.727495  -90.276069    2.5             5        1
# 150193  39.883115  -75.542323    3.0            52        1
# 150205  39.949502  -86.349949    2.5            32        1
# 150231  27.714605  -82.335851    4.0             5        1
# 150313  36.193201  -86.614748    3.0             6        1
#
#                                                attributes  \
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 9       {'RestaurantsAttire': ''casual'', 'Restaurants...
# 97      {'BikeParking': 'True', 'WiFi': 'u'no'', 'Dogs...
# 122     {'BusinessParking': '{'garage': False, 'street...
# 153     {'RestaurantsPriceRange2': '1', 'Caters': 'Tru...
# ...                                                   ...
# 150183  {'RestaurantsReservations': 'False', 'Business...
# 150193  {'BusinessParking': '{'garage': False, 'street...
# 150205  {'BusinessParking': '{'garage': False, 'street...
# 150231  {'GoodForKids': 'True', 'RestaurantsTakeOut': ...
# 150313  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...
#
#                                                categories  \
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 97      Sporting Goods, Sports Wear, Fashion, Restaura...
# 122                    Sandwiches, Fast Food, Restaurants
# 153                       Mexican, Fast Food, Restaurants
# ...                                                   ...
# 150183        Burgers, Restaurants, Fast Food, Sandwiches
# 150193  Caterers, Fast Food, Event Planning & Services...
# 150205  Chicken Shop, Caterers, Fast Food, Restaurants...
# 150231                 Restaurants, Fast Food, Sandwiches
# 150313  Restaurants, Pizza, Fast Food, Chicken Wings, ...
#
#                                                     hours
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 97      {'Monday': '0:0-0:0', 'Tuesday': '10:0-21:0', ...
# 122     {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 153     {'Monday': '0:0-0:0', 'Tuesday': '10:45-22:0',...
# ...                                                   ...
# 150183  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...
# 150193  {'Monday': '0:0-0:0', 'Tuesday': '10:30-21:0',...
# 150205  {'Monday': '0:0-0:0', 'Tuesday': '6:30-21:0', ...
# 150231  {'Monday': '0:0-0:0', 'Tuesday': '9:0-21:0', '...
# 150313  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
#
# [5218 rows x 14 columns]

# %% [markdown]
# # Attribute Analysis

# %%
fastfood[["attributes"]].iloc[0,0]
# Out:
# {'BusinessParking': 'None',
#  'BusinessAcceptsCreditCards': 'True',
#  'RestaurantsAttire': "u'casual'",
#  'OutdoorSeating': 'True',
#  'RestaurantsReservations': 'False',
#  'Caters': 'False',
#  'RestaurantsTakeOut': 'True',
#  'Alcohol': "u'none'",
#  'Ambience': 'None',
#  'GoodForKids': 'True',
#  'RestaurantsPriceRange2': '1',
#  'ByAppointmentOnly': 'False',
#  'CoatCheck': 'False',
#  'DogsAllowed': 'False',
#  'RestaurantsTableService': 'False',
#  'RestaurantsGoodForGroups': 'True',
#  'RestaurantsDelivery': 'True',
#  'WiFi': "u'no'",
#  'WheelchairAccessible': 'True',
#  'HasTV': 'True',
#  'HappyHour': 'False',
#  'DriveThru': 'True',
#  'BikeParking': 'False'}

# %% [markdown]
# ## count numbers of each attributes

# %%
attributes_list = []
for attribute in fastfood["attributes"]:
    attributes_list.extend(attribute.keys())
attr_dict = pd.Series(attributes_list).value_counts().to_dict()
attr_dict
# Out:
# {'RestaurantsDelivery': 5173,
#  'RestaurantsTakeOut': 5114,
#  'RestaurantsPriceRange2': 4797,
#  'BusinessAcceptsCreditCards': 4725,
#  'RestaurantsReservations': 4544,
#  'GoodForKids': 4336,
#  'RestaurantsGoodForGroups': 4316,
#  'BusinessParking': 4210,
#  'Ambience': 4076,
#  'HasTV': 4060,
#  'OutdoorSeating': 4035,
#  'RestaurantsAttire': 4033,
#  'Caters': 3483,
#  'Alcohol': 3429,
#  'WiFi': 3372,
#  'BikeParking': 3349,
#  'DriveThru': 3149,
#  'NoiseLevel': 2880,
#  'GoodForMeal': 2866,
#  'RestaurantsTableService': 1174,
#  'WheelchairAccessible': 667,
#  'DogsAllowed': 600,
#  'HappyHour': 414,
#  'ByAppointmentOnly': 231,
#  'BusinessAcceptsBitcoin': 208,
#  'CoatCheck': 156,
#  'BYOB': 134,
#  'Corkage': 112,
#  'BYOBCorkage': 48,
#  'Music': 36,
#  'BestNights': 20,
#  'Smoking': 20,
#  'GoodForDancing': 14,
#  'RestaurantsCounterService': 4,
#  'Open24Hours': 4,
#  'DietaryRestrictions': 3,
#  'AcceptsInsurance': 2,
#  'AgesAllowed': 2}

# %%
len(attr_dict)
# Out:
# 38

# %% [markdown]
# We count the attributes provided by Fastfood restaurants using the "business.json" file. It turns out to be 38 attributes in total.

# %% [markdown]
# ### To avoid bias in our analysis, we choose attributes that are provided by at least 80% of the businesses.

# %%
attr_list = [k for (k,v) in attr_dict.items() if v >=len(fastfood)*0.8]
attr_list
# Out:
# ['RestaurantsDelivery',
#  'RestaurantsTakeOut',
#  'RestaurantsPriceRange2',
#  'BusinessAcceptsCreditCards',
#  'RestaurantsReservations',
#  'GoodForKids',
#  'RestaurantsGoodForGroups',
#  'BusinessParking']

# %% [markdown]
# ## transform the attributes to a dataframe

# %%
df_attributes = pd.json_normalize(fastfood['attributes'])

# %%
df_attributes = df_attributes[attr_list]

# %%
df_attributes["business_id"] = fastfood['business_id'].values #add business_id
df_attributes["stars"] = fastfood['stars'].values #add star rating

# %%
df_attributes
# Out:
#      RestaurantsDelivery RestaurantsTakeOut RestaurantsPriceRange2  \
# 0                   True               True                      1
# 1                   True               True                      1
# 2                    NaN                NaN                    NaN
# 3                   True               True                      1
# 4                   True               True                      1
# ...                  ...                ...                    ...
# 5213                True               True                      1
# 5214                True               True                      1
# 5215                True               True                    NaN
# 5216                True               True                      1
# 5217                True               True                      1
#
#      BusinessAcceptsCreditCards RestaurantsReservations GoodForKids  \
# 0                          True                   False        True
# 1                          True                   False        True
# 2                          True                   False         NaN
# 3                          True                   False        True
# 4                          True                   False        True
# ...                         ...                     ...         ...
# 5213                       True                   False        True
# 5214                       True                   False        True
# 5215                       True                   False         NaN
# 5216                       True                   False        True
# 5217                       True                   False       False
#
#      RestaurantsGoodForGroups  \
# 0                        True
# 1                       False
# 2                         NaN
# 3                        True
# 4                       False
# ...                       ...
# 5213                    False
# 5214                     True
# 5215                      NaN
# 5216                     True
# 5217                    False
#
#                                         BusinessParking  \
# 0                                                  None
# 1     {'garage': False, 'street': False, 'validated'...
# 2     {'garage': False, 'street': False, 'validated'...
# 3     {'garage': False, 'street': False, 'validated'...
# 4     {'garage': False, 'street': False, 'validated'...
# ...                                                 ...
# 5213                                                NaN
# 5214  {'garage': False, 'street': False, 'validated'...
# 5215  {'garage': False, 'street': False, 'validated'...
# 5216                                                NaN
# 5217  {'garage': False, 'street': False, 'validated'...
#
#                  business_id  stars
# 0     CF33F8-E6oudUQ46HnavjQ    2.0
# 1     bBDDEgkFA1Otx9Lfe7BZUQ    1.5
# 2     knQ4vIgx-r85kjlWVVjcpQ    4.5
# 3     VZzivJEbmHItOxNXJB3SpA    2.5
# 4     aNtKyc2rr-uK5cqzY9TVQQ    3.0
# ...                      ...    ...
# 5213  _rM0QpGDdFk3Vux2kltQsQ    2.5
# 5214  0COlL5IKRu5sdWIsEiQAZg    3.0
# 5215  Agh0Z_PACmbdEpLyjvuwZg    2.5
# 5216  C96ynw3G1KrqBOdafxbTKw    4.0
# 5217  sf_oQ62L8UEnOOLf00nNGA    3.0
#
# [5218 rows x 10 columns]

# %%
df_attributes
# Out:
#      RestaurantsDelivery RestaurantsTakeOut RestaurantsPriceRange2  \
# 0                   True               True                      1
# 1                   True               True                      1
# 2                    NaN                NaN                    NaN
# 3                   True               True                      1
# 4                   True               True                      1
# ...                  ...                ...                    ...
# 5213                True               True                      1
# 5214                True               True                      1
# 5215                True               True                    NaN
# 5216                True               True                      1
# 5217                True               True                      1
#
#      BusinessAcceptsCreditCards RestaurantsReservations GoodForKids  \
# 0                          True                   False        True
# 1                          True                   False        True
# 2                          True                   False         NaN
# 3                          True                   False        True
# 4                          True                   False        True
# ...                         ...                     ...         ...
# 5213                       True                   False        True
# 5214                       True                   False        True
# 5215                       True                   False         NaN
# 5216                       True                   False        True
# 5217                       True                   False       False
#
#      RestaurantsGoodForGroups  \
# 0                        True
# 1                       False
# 2                         NaN
# 3                        True
# 4                       False
# ...                       ...
# 5213                    False
# 5214                     True
# 5215                      NaN
# 5216                     True
# 5217                    False
#
#                                         BusinessParking  \
# 0                                                  None
# 1     {'garage': False, 'street': False, 'validated'...
# 2     {'garage': False, 'street': False, 'validated'...
# 3     {'garage': False, 'street': False, 'validated'...
# 4     {'garage': False, 'street': False, 'validated'...
# ...                                                 ...
# 5213                                                NaN
# 5214  {'garage': False, 'street': False, 'validated'...
# 5215  {'garage': False, 'street': False, 'validated'...
# 5216                                                NaN
# 5217  {'garage': False, 'street': False, 'validated'...
#
#                  business_id  stars
# 0     CF33F8-E6oudUQ46HnavjQ    2.0
# 1     bBDDEgkFA1Otx9Lfe7BZUQ    1.5
# 2     knQ4vIgx-r85kjlWVVjcpQ    4.5
# 3     VZzivJEbmHItOxNXJB3SpA    2.5
# 4     aNtKyc2rr-uK5cqzY9TVQQ    3.0
# ...                      ...    ...
# 5213  _rM0QpGDdFk3Vux2kltQsQ    2.5
# 5214  0COlL5IKRu5sdWIsEiQAZg    3.0
# 5215  Agh0Z_PACmbdEpLyjvuwZg    2.5
# 5216  C96ynw3G1KrqBOdafxbTKw    4.0
# 5217  sf_oQ62L8UEnOOLf00nNGA    3.0
#
# [5218 rows x 10 columns]

# %% [markdown]
# ### "BusinessParking" has 5 types: Garage/Street/Validated/Lot/Valet

# %%
len(df_attributes['BusinessParking'].loc[lambda x: x.isna()])
# Out:
# 1008

# %%
df_attributes['BusinessParking_parsed'] = df_attributes['BusinessParking'].apply(lambda x: ast.literal_eval(str(x)) if isinstance(x, str) else np.nan)

# %%
df_attributes = pd.merge(df_attributes, df_attributes['BusinessParking_parsed'].apply(pd.Series), left_index=True, right_index=True)
df_attributes.drop(['BusinessParking', 'BusinessParking_parsed', 0], axis=1, inplace=True)
df_attributes
# Out:
#      RestaurantsDelivery RestaurantsTakeOut RestaurantsPriceRange2  \
# 0                   True               True                      1
# 1                   True               True                      1
# 2                    NaN                NaN                    NaN
# 3                   True               True                      1
# 4                   True               True                      1
# ...                  ...                ...                    ...
# 5213                True               True                      1
# 5214                True               True                      1
# 5215                True               True                    NaN
# 5216                True               True                      1
# 5217                True               True                      1
#
#      BusinessAcceptsCreditCards RestaurantsReservations GoodForKids  \
# 0                          True                   False        True
# 1                          True                   False        True
# 2                          True                   False         NaN
# 3                          True                   False        True
# 4                          True                   False        True
# ...                         ...                     ...         ...
# 5213                       True                   False        True
# 5214                       True                   False        True
# 5215                       True                   False         NaN
# 5216                       True                   False        True
# 5217                       True                   False       False
#
#      RestaurantsGoodForGroups             business_id  stars garage    lot  \
# 0                        True  CF33F8-E6oudUQ46HnavjQ    2.0    NaN    NaN
# 1                       False  bBDDEgkFA1Otx9Lfe7BZUQ    1.5  False  False
# 2                         NaN  knQ4vIgx-r85kjlWVVjcpQ    4.5  False   True
# 3                        True  VZzivJEbmHItOxNXJB3SpA    2.5  False  False
# 4                       False  aNtKyc2rr-uK5cqzY9TVQQ    3.0  False   True
# ...                       ...                     ...    ...    ...    ...
# 5213                    False  _rM0QpGDdFk3Vux2kltQsQ    2.5    NaN    NaN
# 5214                     True  0COlL5IKRu5sdWIsEiQAZg    3.0  False   True
# 5215                      NaN  Agh0Z_PACmbdEpLyjvuwZg    2.5  False   True
# 5216                     True  C96ynw3G1KrqBOdafxbTKw    4.0    NaN    NaN
# 5217                    False  sf_oQ62L8UEnOOLf00nNGA    3.0  False  False
#
#      street  valet validated
# 0       NaN    NaN       NaN
# 1     False  False     False
# 2     False  False     False
# 3     False  False     False
# 4     False  False     False
# ...     ...    ...       ...
# 5213    NaN    NaN       NaN
# 5214  False  False     False
# 5215  False  False     False
# 5216    NaN    NaN       NaN
# 5217  False  False     False
#
# [5218 rows x 14 columns]

# %%
BusinessParking = df_attributes.loc[~(pd.isna(df_attributes["garage"])), :]
BusinessParking = BusinessParking.loc[~(pd.isna(BusinessParking["street"])), :]
BusinessParking = BusinessParking.loc[~(pd.isna(BusinessParking["validated"])), :]
BusinessParking = BusinessParking.loc[~(pd.isna(BusinessParking["lot"])), :]
BusinessParking = BusinessParking.loc[~(pd.isna(BusinessParking["valet"])), :]

# %%
BusinessParking['garage'] = BusinessParking['garage'].replace([True], "True").replace([False], "False")
BusinessParking['street'] = BusinessParking['street'].replace([True], "True").replace([False], "False")
BusinessParking['validated'] = BusinessParking['validated'].replace([True], "True").replace([False], "False")
BusinessParking['lot'] = BusinessParking['lot'].replace([True], "True").replace([False], "False")
BusinessParking['valet'] = BusinessParking['valet'].replace([True], "True").replace([False], "False")

# %%
BusinessParking
# Out:
#      RestaurantsDelivery RestaurantsTakeOut RestaurantsPriceRange2  \
# 1                   True               True                      1
# 2                    NaN                NaN                    NaN
# 3                   True               True                      1
# 4                   True               True                      1
# 5                   True               True                      1
# ...                  ...                ...                    ...
# 5211                True               True                      2
# 5212                True               True                      1
# 5214                True               True                      1
# 5215                True               True                    NaN
# 5217                True               True                      1
#
#      BusinessAcceptsCreditCards RestaurantsReservations GoodForKids  \
# 1                          True                   False        True
# 2                          True                   False         NaN
# 3                          True                   False        True
# 4                          True                   False        True
# 5                          True                   False        True
# ...                         ...                     ...         ...
# 5211                       True                    True        True
# 5212                       True                   False        True
# 5214                       True                   False        True
# 5215                       True                   False         NaN
# 5217                       True                   False       False
#
#      RestaurantsGoodForGroups             business_id  stars garage    lot  \
# 1                       False  bBDDEgkFA1Otx9Lfe7BZUQ    1.5  False  False
# 2                         NaN  knQ4vIgx-r85kjlWVVjcpQ    4.5  False   True
# 3                        True  VZzivJEbmHItOxNXJB3SpA    2.5  False  False
# 4                       False  aNtKyc2rr-uK5cqzY9TVQQ    3.0  False   True
# 5                        True  G4lRmwDHdvhZAhmtlsYYBw    1.5  False   True
# ...                       ...                     ...    ...    ...    ...
# 5211                     True  y77Rf5aezhj92pi1juN93g    4.0  False  False
# 5212                     True  BzPTw9daJW8ToqTc7QiHFw    2.5  False   True
# 5214                     True  0COlL5IKRu5sdWIsEiQAZg    3.0  False   True
# 5215                      NaN  Agh0Z_PACmbdEpLyjvuwZg    2.5  False   True
# 5217                    False  sf_oQ62L8UEnOOLf00nNGA    3.0  False  False
#
#      street  valet validated
# 1     False  False     False
# 2     False  False     False
# 3     False  False     False
# 4     False  False     False
# 5     False  False     False
# ...     ...    ...       ...
# 5211   True  False     False
# 5212  False  False     False
# 5214  False  False     False
# 5215  False  False     False
# 5217  False  False     False
#
# [3529 rows x 14 columns]

# %% [markdown]
# # ANOVA

# %% [markdown]
# Conduct the one-way ANOVA for True/False attributes

# %%
attributes_TF = ['RestaurantsDelivery', 'RestaurantsTakeOut', 'BusinessAcceptsCreditCards', 'RestaurantsReservations', 
                      'GoodForKids', 'RestaurantsGoodForGroups']
result_TF = []

for i in attributes_TF:
    res = stats.f_oneway(df_attributes['stars'][df_attributes[i] == 'False'], 
                            df_attributes['stars'][df_attributes[i] == 'True'])
    result_TF.append(res)

# %%
result_TF
# Out:
# [F_onewayResult(statistic=279.2977265826459, pvalue=4.511578487237944e-61),
#  F_onewayResult(statistic=158.55837396923133, pvalue=7.997000707232563e-36),
#  F_onewayResult(statistic=18.910547585508574, pvalue=1.3988355650102912e-05),
#  F_onewayResult(statistic=96.43061276807767, pvalue=1.548510835507224e-22),
#  F_onewayResult(statistic=64.63588191791008, pvalue=1.1526381865111836e-15),
#  F_onewayResult(statistic=57.39653513979277, pvalue=4.334152180869036e-14)]

# %% [markdown]
# Conduct the one-way ANOVA for RestaurantsPriceRange2

# %%
res_price_range = stats.f_oneway(df_attributes['stars'][df_attributes["RestaurantsPriceRange2"] == '1'], 
                                 df_attributes['stars'][df_attributes["RestaurantsPriceRange2"] == '2'],
                                 df_attributes['stars'][df_attributes["RestaurantsPriceRange2"] == '3'], 
                                 df_attributes['stars'][df_attributes["RestaurantsPriceRange2"] == '4'])
res_price_range
# Out:
# F_onewayResult(statistic=96.76568579483046, pvalue=8.328201280651748e-61)

# %% [markdown]
# Conduct the one-way ANOVA for BusinessParking

# %%
BusinessParking_list = ["garage", "street", "validated", "lot", "valet"]
result_list_BusinessParking = []

for i in BusinessParking_list:
    result = stats.f_oneway(BusinessParking['stars'][BusinessParking[i] == 'False'], 
                            BusinessParking['stars'][BusinessParking[i] == 'True'])
    result_list_BusinessParking.append(result)

# %%
result_list_BusinessParking
# Out:
# [F_onewayResult(statistic=28.37879944914653, pvalue=1.0599766111237605e-07),
#  F_onewayResult(statistic=178.38037096766683, pvalue=9.941243936891748e-40),
#  F_onewayResult(statistic=13.685719642633314, pvalue=0.00021938669205304125),
#  F_onewayResult(statistic=46.267152261499064, pvalue=1.2070425966281514e-11),
#  F_onewayResult(statistic=5.62334122280382, pvalue=0.017776246755424028)]

# %% [markdown]
# ### From the ANOVA Analysis, we found that all attributes we selected are significant.

# %% [markdown]
# ## average rating: not to high

# %%
np.mean(df_attributes['stars'])
# Out:
# 2.5666922192410886

# %% [markdown]
# ## The distribution of restaurant ratings

# %%
df_attributes.replace('None', np.nan, inplace=True)

# %%
ax = sns.countplot(y='RestaurantsDelivery', hue = 'stars',data=df_attributes, palette = "magma")
ax.legend(loc='lower right')
ax.get_legend().set_title("stars")
plt.title('Distribution of Restaurants Delivery',size = 18)
plt.xlabel("count",size = 14)
plt.xticks(size = 14)
plt.ylabel("Restaurants Delivery",size = 14)
plt.yticks(size = 14)
plt.show()

# %%
ax = sns.countplot(y='RestaurantsTakeOut', hue = 'stars',data=df_attributes, palette = "magma")
ax.legend(loc='lower right')
ax.get_legend().set_title("stars")
plt.title('Distribution of Restaurants Take Out',size = 18)
plt.xlabel("count",size = 14)
plt.xticks(size = 14)
plt.ylabel("Restaurants Take Out",size = 14)
plt.yticks(size = 14)
plt.show()

# %%
ax = sns.countplot(y='RestaurantsPriceRange2', hue = 'stars',data=df_attributes, palette = "magma")
ax.legend(loc='lower right')
ax.get_legend().set_title("stars")
plt.title('Distribution of Restaurants Price Range',size = 18)
plt.xlabel("count",size = 14)
plt.xticks(size = 14)
plt.ylabel("Restaurants Price Range",size = 14)
plt.yticks(size = 14)
plt.show()

# %%
ax = sns.countplot(y='BusinessAcceptsCreditCards', hue = 'stars',data=df_attributes, palette = "magma")
ax.legend(loc='lower right')
ax.get_legend().set_title("stars")
plt.title('Distribution of Business Accepts Credit Cards',size = 18)
plt.xlabel("count",size = 14)
plt.xticks(size = 14)
plt.ylabel("Business Accepts Credit Cards",size = 14)
plt.yticks(size = 14)
plt.show()

# %%
ax = sns.countplot(y='RestaurantsReservations', hue = 'stars',data=df_attributes, palette = "magma")
ax.legend(loc='lower right')
ax.get_legend().set_title("stars")
plt.title('Distribution of Restaurants Reservations',size = 18)
plt.xlabel("count",size = 14)
plt.xticks(size = 14)
plt.ylabel("Restaurants Reservations",size = 14)
plt.yticks(size = 14)
plt.show()

# %%
ax = sns.countplot(y='GoodForKids', hue = 'stars',data=df_attributes, palette = "magma")
ax.legend(loc='lower right')
ax.get_legend().set_title("stars")
plt.title('Distribution of Restaurants Good For Kids',size = 18)
plt.xlabel("count",size = 14)
plt.xticks(size = 14)
plt.ylabel("Restaurants Good For Kids",size = 14)
plt.yticks(size = 14)
plt.show()

# %%
ax = sns.countplot(y='RestaurantsGoodForGroups', hue = 'stars',data=df_attributes, palette = "magma")
ax.legend(loc='lower right')
ax.get_legend().set_title("stars")
plt.title('Distribution of Restaurants Good For Groups',size = 18)
plt.xlabel("count",size = 14)
plt.xticks(size = 14)
plt.ylabel("Restaurants Good For Groups",size = 14)
plt.yticks(size = 14)
plt.show()

# %%
# business parking
for i in ["garage",'street','validated','lot','valet']:
    ax = sns.countplot(y=i, hue = 'stars',data=df_attributes, palette = "magma")
    ax.legend(loc='lower right')
    ax.get_legend().set_title("stars")
    plt.title(f'Distribution of rates for restaurants {i} parking',size = 18)
    plt.xlabel("count",size = 14)
    plt.xticks(size = 14)
    plt.ylabel(f"{i} parking",size = 14)
    plt.yticks(size = 14)
    plt.show()

# %% [markdown]
# 1. In these attributes, we could see that for most of fast food restaurants, a common feature is that they offer take out or delivery.
# 2. The price of them are mostly in range 1 or 2, which is an affordable price for most of the customers.
# 3. For payment, they mostly accept credit cards.
# 4. Most fast food restaurants do not accept reservations.
# 5. Most fast food restaurants are good for groups and kids.
# 6. Most fast food restaurants do not offer garage/street/validated parking; no fast food restaurant has valet parking; lot parking is the most common way of parking for fast food restaurants.

# %%
df_b = pd.read_json('yelp_dataset_2022/business.json', lines=True)

# %%
df_b["state"].value_counts()
us_states = ["AL", "KY", "OH", "AK", "LA", "OK", "AZ", "ME", "OR", "AR", "MD", "PA", "AS",
             "MA", "PR", "CA", "MI", "RI", "CO", "MN", "SC", "CT", "MS", "SD", "DE", "MO",
             "TN", "DC", "MT", "TX", "FL", "NE", "TT", "GA", "NV", "UT", "GU", "NH", "VT",
             "HI", "NJ", "VA","ID", "NM", "VI", "IL", "NY", "WA", "IN", "NC", "WV", "IA", 
             "ND", "WI", "KS", "MP", "WY"]
df_b = df_b[df_b['state'].isin(us_states)]

# %% [markdown]
# # Read review.json file

# %%
review_json_path = 'yelp_dataset_2022/review.json'

# %% [markdown]
# Identifying the data type of each column can reduce memory usage. Yelp provided documentation for their dataset on websit:https://www.yelp.com/dataset/documentation/main, so we can set the data type of each column.
#
# Since we set the chunk size as 1000000, Pandas will read 1000000 lines each time. In review.json, there are more than 6 million reviews (rows). Reducing the chunk size might be easier to load and check the results faster.

# %%
size = 1000000
reviews = pd.read_json(review_json_path, lines=True, 
                    dtype={'review_id':str,'user_id':str,
                           'business_id':str,'stars':int,
                           'date':str,'text':str,'useful':int,
                           'funny':int,'cool':int},
                    chunksize=size)

# %% [markdown]
# # the fastfood restaurants that are closed

# %%
df_closed = df_b[df_b['is_open']==0]

# %%
closed_fastfood = df_closed[df_closed.categories.str.contains('Fast Food',case=True,na=False)]

# %%
closed_fastfood
# Out:
#                    business_id                              name  \
# 474     Dl1alpHSJE4_iB0MGKRLXw                    Johnny Rockets
# 496     RsTF2skxLcp6qo9FdnA5PA                         Pizza Hut
# 768     _-SSObHzljeA11HAF0lIrQ                          Hardee's
# 784     ZfWVso8VlT0VN14rxVHccQ                   Candida's Pizza
# 921     vLT1KtrA9bWvjFOg-0xVIg                 Pieology Pizzeria
# ...                        ...                               ...
# 149897  DkdMQyXlJbkqhq3XCnoLlQ                       Taco John's
# 150111  qjtELTt9fdIwoi_xGNN21g            Chipotle Mexican Grill
# 150154  mQsXDZ2EGBJ5wj2VI4zr_Q  Erbert & Gerbert's Sandwich Shop
# 150226  oNeZmmoO7OCyT2vSsVnGKw        Coney Island Sandwich Shop
# 150248  5ufcSii8MbAI3Yn5BQq2tA                           Denny's
#
#                                                   address           city  \
# 474                             5555 St. Louis Mills Blvd      Hazelwood
# 496     16 Summit Sq, Store 2B, Route 413 & Doublewood...      Langhorne
# 768                               4116 W Hillsborough Ave          Tampa
# 784                                       35 E Butler Ave         Ambler
# 921                             7000 Hollister Ave, Ste F         Goleta
# ...                                                   ...            ...
# 149897                               5068 Murfreesboro Rd      La Vergne
# 150111                                     400 W Route 38     Moorestown
# 150154                                    102 E Carmel Dr         Carmel
# 150226                  250 Dr Martin Luther King Jr St N  St Petersburg
# 150248                                   1096 Shighway Dr         Fenton
#
#        state postal_code   latitude   longitude  stars  review_count  is_open  \
# 474       MO       63042  38.786090  -90.415775    2.0             6        0
# 496       PA       19047  40.217860  -74.926634    1.5            18        0
# 768       FL       33614  27.995521  -82.512474    2.5            27        0
# 784       PA       19002  40.154294  -75.222913    2.5            22        0
# 921       CA       93117  34.430453 -119.872345    3.5           131        0
# ...      ...         ...        ...         ...    ...           ...      ...
# 149897    TN       37086  36.021876  -86.583757    2.5            29        0
# 150111    NJ       08057  39.943481  -74.964743    3.0            63        0
# 150154    IN       46032  39.961425  -86.125405    3.5            29        0
# 150226    FL       33705  27.774380  -82.646986    4.0           109        0
# 150248    MO       63026  38.541507  -90.467582    2.5            11        0
#
#                                                attributes  \
# 474     {'RestaurantsPriceRange2': '1', 'OutdoorSeatin...
# 496     {'RestaurantsAttire': ''casual'', 'Restaurants...
# 768     {'GoodForKids': 'True', 'OutdoorSeating': 'Fal...
# 784     {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 921     {'RestaurantsAttire': ''casual'', 'Alcohol': '...
# ...                                                   ...
# 149897  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...
# 150111  {'RestaurantsDelivery': 'False', 'Caters': 'Tr...
# 150154  {'OutdoorSeating': 'False', 'RestaurantsReserv...
# 150226  {'RestaurantsPriceRange2': '1', 'RestaurantsDe...
# 150248  {'GoodForKids': 'True', 'OutdoorSeating': 'Fal...
#
#                                                categories  \
# 474     Food, Fast Food, Sandwiches, Restaurants, Amer...
# 496     Italian, Restaurants, Fast Food, Chicken Wings...
# 768                       Restaurants, Fast Food, Burgers
# 784                         Restaurants, Pizza, Fast Food
# 921     Restaurants, Gluten-Free, Pizza, Vegan, Fast Food
# ...                                                   ...
# 149897                    Restaurants, Fast Food, Mexican
# 150111                    Restaurants, Mexican, Fast Food
# 150154           Soup, Sandwiches, Restaurants, Fast Food
# 150226       Restaurants, Fast Food, Sandwiches, Hot Dogs
# 150248  American (Traditional), Diners, Breakfast & Br...
#
#                                                     hours
# 474     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 496     {'Monday': '10:30-23:0', 'Tuesday': '10:30-23:...
# 768     {'Monday': '5:0-21:0', 'Tuesday': '5:0-21:0', ...
# 784     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 921     {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...
# ...                                                   ...
# 149897  {'Monday': '6:0-23:0', 'Tuesday': '6:0-23:0', ...
# 150111  {'Monday': '10:45-22:0', 'Tuesday': '10:45-22:...
# 150154  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 150226  {'Monday': '10:0-16:0', 'Tuesday': '10:0-16:0'...
# 150248  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
#
# [910 rows x 14 columns]

# %% [markdown]
# ## Merge Review.json and Business.json file based on business_id

# %%
chunk_list = []
for chunk in reviews:
    # Merge reviews.json and fastfood business file based on business_id
    chunk_merged = pd.merge(closed_fastfood, chunk, on='business_id', how='inner')
    # Show feedback on progress
    print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
    chunk_list.append(chunk_merged)
# Out:
# 4683 out of 1,000,000 related reviews
# 4270 out of 1,000,000 related reviews
# 3889 out of 1,000,000 related reviews
# 3764 out of 1,000,000 related reviews
# 3879 out of 1,000,000 related reviews
# 3975 out of 1,000,000 related reviews
# 3812 out of 1,000,000 related reviews

# %%
# concatenate all relevant data to a dataframe
df_closed = pd.concat(chunk_list, ignore_index=True, join='outer', axis=0)
df_closed
# Out:
#                   business_id            name                    address  \
# 0      Dl1alpHSJE4_iB0MGKRLXw  Johnny Rockets  5555 St. Louis Mills Blvd
# 1      Dl1alpHSJE4_iB0MGKRLXw  Johnny Rockets  5555 St. Louis Mills Blvd
# 2      Dl1alpHSJE4_iB0MGKRLXw  Johnny Rockets  5555 St. Louis Mills Blvd
# 3      Dl1alpHSJE4_iB0MGKRLXw  Johnny Rockets  5555 St. Louis Mills Blvd
# 4      Dl1alpHSJE4_iB0MGKRLXw  Johnny Rockets  5555 St. Louis Mills Blvd
# ...                       ...             ...                        ...
# 28267  5ufcSii8MbAI3Yn5BQq2tA         Denny's           1096 Shighway Dr
# 28268  5ufcSii8MbAI3Yn5BQq2tA         Denny's           1096 Shighway Dr
# 28269  5ufcSii8MbAI3Yn5BQq2tA         Denny's           1096 Shighway Dr
# 28270  5ufcSii8MbAI3Yn5BQq2tA         Denny's           1096 Shighway Dr
# 28271  5ufcSii8MbAI3Yn5BQq2tA         Denny's           1096 Shighway Dr
#
#             city state postal_code   latitude  longitude  stars_x  \
# 0      Hazelwood    MO       63042  38.786090 -90.415775      2.0
# 1      Hazelwood    MO       63042  38.786090 -90.415775      2.0
# 2      Hazelwood    MO       63042  38.786090 -90.415775      2.0
# 3      Hazelwood    MO       63042  38.786090 -90.415775      2.0
# 4      Hazelwood    MO       63042  38.786090 -90.415775      2.0
# ...          ...   ...         ...        ...        ...      ...
# 28267     Fenton    MO       63026  38.541507 -90.467582      2.5
# 28268     Fenton    MO       63026  38.541507 -90.467582      2.5
# 28269     Fenton    MO       63026  38.541507 -90.467582      2.5
# 28270     Fenton    MO       63026  38.541507 -90.467582      2.5
# 28271     Fenton    MO       63026  38.541507 -90.467582      2.5
#
#        review_count  ...                                         categories  \
# 0                 6  ...  Food, Fast Food, Sandwiches, Restaurants, Amer...
# 1                 6  ...  Food, Fast Food, Sandwiches, Restaurants, Amer...
# 2                 6  ...  Food, Fast Food, Sandwiches, Restaurants, Amer...
# 3                 6  ...  Food, Fast Food, Sandwiches, Restaurants, Amer...
# 4                 6  ...  Food, Fast Food, Sandwiches, Restaurants, Amer...
# ...             ...  ...                                                ...
# 28267            11  ...  American (Traditional), Diners, Breakfast & Br...
# 28268            11  ...  American (Traditional), Diners, Breakfast & Br...
# 28269            11  ...  American (Traditional), Diners, Breakfast & Br...
# 28270            11  ...  American (Traditional), Diners, Breakfast & Br...
# 28271            11  ...  American (Traditional), Diners, Breakfast & Br...
#
#                                                    hours  \
# 0      {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 1      {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2      {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 3      {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 4      {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# ...                                                  ...
# 28267  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 28268  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 28269  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 28270  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 28271  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
#
#                     review_id                 user_id stars_y useful  funny  \
# 0      4SEXTQLtMxIyK1Lo59GBFA  2RUoIlkN7ncxXfen3RLtdg       1      1      0
# 1      8wggawlh1tdk3rW_xOrGXw  pQrWjL22u-vSWMwS9yZ_Yg       3      0      0
# 2      st0bXvJryBeObZJ7CLaZyQ  E_OOZjrlgDTTCHT5p2tG_w       4      2      1
# 3      pTkDE-Ue2Au-oFfzZ4IAcw  DSCj0grbiqsSVtq-5H9oyQ       1      0      0
# 4      As3d4pRlm6T73lm7hpp4sA  FtYiSgEieRWtkqJJ6Zkzhg       1      0      0
# ...                       ...                     ...     ...    ...    ...
# 28267  AaeZ2N5qj6UN69sJ3NEO-Q  0yDJnbmZOR-3OkpG1rTmDQ       5      1      1
# 28268  QNLLlhAZmEbD0Gg2ADP9Kg  oYC8YkIQq3UFawY3d8MZHg       1      3      0
# 28269  _F61WTdxURJlk5fp2yJyjw  YP8s2GVRg9KNepakB99y5w       1      1      0
# 28270  exehVcBvcALmIVIq8pJMRw  kncH-kJB2cUc6WIaCdWpKA       1      0      0
# 28271  8WCcEvYWVPlp_GD8sf2OYQ  S5x3bBh7tXL70N2gLZn1ZQ       5      1      0
#
#        cool                                               text  \
# 0         1  Horrible, horrible service. I took friends who...
# 1         0  Great 50"s style restaurant.  walk up as well ...
# 2         1  I enjoy myself some diner food every once and ...
# 3         0  I have never had a poor experience at Johnny R...
# 4         0  I hate to use hyperbole but Johnny Rockets is ...
# ...     ...                                                ...
# 28267     0  After following Sunday mass we stop by Denny's...
# 28268     0  Worst experience at a Denny's I have ever had....
# 28269     0  Never again!  We had just been to the Wolf San...
# 28270     0  This place is so hit or miss, I'd just as soon...
# 28271     0  Wow!  Who gives you an extra to-go cup of hot ...
#
#                       date
# 0      2012-06-28 15:53:07
# 1      2010-04-06 19:33:04
# 2      2008-11-22 21:07:16
# 3      2013-08-23 00:55:41
# 4      2012-01-20 04:02:29
# ...                    ...
# 28267  2016-02-29 05:03:58
# 28268  2016-07-21 01:13:32
# 28269  2017-07-15 22:10:59
# 28270  2013-04-12 16:07:58
# 28271  2014-11-25 15:50:59
#
# [28272 rows x 22 columns]

# %%
df_closed.to_csv("data_closed.csv")

# %% [markdown]
# # the fastfood restaurants that are open

# %%
df_open = df_b[df_b['is_open']==1]
df_open = df_open[df_b['stars']<=2] 
open_fastfood = df_open[df_open.categories.str.contains('Fast Food',case=True,na=False)]
open_fastfood
# Out:
# /var/folders/zh/j34n7hk15kb02m2n0kr685j40000gn/T/ipykernel_76075/2336299240.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_open = df_open[df_b['stars']<=2]
#                    business_id            name                        address  \
# 5       CF33F8-E6oudUQ46HnavjQ  Sonic Drive-In                  615 S Main St
# 9       bBDDEgkFA1Otx9Lfe7BZUQ  Sonic Drive-In            2312 Dickerson Pike
# 161     G4lRmwDHdvhZAhmtlsYYBw         Wendy's                741 Thompson Ln
# 193     yM8LlTInbQH4FwWC97lz6w      McDonald's               1919 S Jefferson
# 199     O1oZpbZNDMH_gz8DhsZCdA         Wendy's            700 E. Hunting Park
# ...                        ...             ...                            ...
# 149770  ewZeX023iPD2grGY3aL4zw          Arby's               Pilot Travel Ctr
# 149835  N9L1B3TD57wyDl7f3Awlcg             KFC                 609 Naamans Rd
# 149963  iNKg6firpzD5u5O1Gqd0HA       Taco Bell       12420 St Charles Rock Rd
# 149976  8Tg3imlkSI8ugCDM4bpSeg     Chick-fil-A              2000 Belmont Blvd
# 150087  hezQG50YXqdgxkhl2R9OuQ       Taco Bell  7620 West Hillsborough Avenue
#
#                 city state postal_code   latitude  longitude  stars  \
# 5       Ashland City    TN       37015  36.269593 -87.058943    2.0
# 9          Nashville    TN       37207  36.208102 -86.768170    1.5
# 161        Nashville    TN       37204  36.112076 -86.767446    1.5
# 193        St. Louis    MO       63104  38.612495 -90.221942    1.5
# 199     Philadelphia    PA       19124  40.012141 -75.115015    1.5
# ...              ...   ...         ...        ...        ...    ...
# 149770          Troy    IL       62294  38.731747 -89.909024    2.0
# 149835      Claymont    DE       19703  39.817152 -75.457245    1.0
# 149963     Bridgeton    MO       63044  38.754822 -90.430455    1.5
# 149976     Nashville    TN       37212  36.132446 -86.795202    1.5
# 150087         Tampa    FL       33615  27.996400 -82.565400    1.5
#
#         review_count  is_open  \
# 5                  6        1
# 9                 10        1
# 161               37        1
# 193              100        1
# 199               15        1
# ...              ...      ...
# 149770             5        1
# 149835            31        1
# 149963            20        1
# 149976             6        1
# 150087            30        1
#
#                                                attributes  \
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 9       {'RestaurantsAttire': ''casual'', 'Restaurants...
# 161     {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 193     {'Alcohol': 'u'none'', 'BikeParking': 'True', ...
# 199     {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# ...                                                   ...
# 149770  {'RestaurantsReservations': 'False', 'GoodForK...
# 149835  {'RestaurantsTakeOut': 'True', 'WiFi': ''no'',...
# 149963  {'BikeParking': 'True', 'RestaurantsGoodForGro...
# 149976  {'RestaurantsReservations': 'False', 'Caters':...
# 150087  {'OutdoorSeating': 'False', 'RestaurantsTakeOu...
#
#                                                categories  \
# 5       Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 9       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 161                       Burgers, Restaurants, Fast Food
# 193     Fast Food, Restaurants, Food, Burgers, Coffee ...
# 199                       Burgers, Restaurants, Fast Food
# ...                                                   ...
# 149770  Burgers, Delis, Fast Food, Sandwiches, Restaur...
# 149835  Chicken Shop, Chicken Wings, Fast Food, Restau...
# 149963  Fast Food, Breakfast & Brunch, Restaurants, Ta...
# 149976  Caterers, Chicken Shop, Event Planning & Servi...
# 150087  Fast Food, Restaurants, Breakfast & Brunch, Ta...
#
#                                                     hours
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 161     {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...
# 193     {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 199     {'Monday': '10:0-2:0', 'Tuesday': '10:0-2:0', ...
# ...                                                   ...
# 149770                                               None
# 149835  {'Monday': '10:30-23:0', 'Tuesday': '10:30-23:...
# 149963  {'Monday': '8:0-2:0', 'Tuesday': '8:0-2:0', 'W...
# 149976  {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:0', ...
# 150087  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
#
# [2238 rows x 14 columns]

# %%
review_json_path = 'yelp_dataset_2022/review.json'

# %%
size = 1000000
reviews = pd.read_json(review_json_path, lines=True, 
                    dtype={'review_id':str,'user_id':str,
                           'business_id':str,'stars':int,
                           'date':str,'text':str,'useful':int,
                           'funny':int,'cool':int},
                    chunksize=size)

# %%
chunk_list2 = []
for chunk in reviews:
    # Merge reviews.json and fastfood business file based on business_id
    chunk_merged = pd.merge(open_fastfood, chunk, on='business_id', how='inner')
    # Show feedback on progress
    print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
    chunk_list2.append(chunk_merged)
# Out:
# 7385 out of 1,000,000 related reviews
# 8372 out of 1,000,000 related reviews
# 8233 out of 1,000,000 related reviews
# 8601 out of 1,000,000 related reviews
# 8539 out of 1,000,000 related reviews
# 7391 out of 1,000,000 related reviews
# 8833 out of 1,000,000 related reviews

# %%
# concatenate all relevant data to a dataframe
df_open = pd.concat(chunk_list2, ignore_index=True, join='outer', axis=0)
df_open
# Out:
#                   business_id            name                        address  \
# 0      CF33F8-E6oudUQ46HnavjQ  Sonic Drive-In                  615 S Main St
# 1      CF33F8-E6oudUQ46HnavjQ  Sonic Drive-In                  615 S Main St
# 2      CF33F8-E6oudUQ46HnavjQ  Sonic Drive-In                  615 S Main St
# 3      CF33F8-E6oudUQ46HnavjQ  Sonic Drive-In                  615 S Main St
# 4      CF33F8-E6oudUQ46HnavjQ  Sonic Drive-In                  615 S Main St
# ...                       ...             ...                            ...
# 57349  hezQG50YXqdgxkhl2R9OuQ       Taco Bell  7620 West Hillsborough Avenue
# 57350  hezQG50YXqdgxkhl2R9OuQ       Taco Bell  7620 West Hillsborough Avenue
# 57351  hezQG50YXqdgxkhl2R9OuQ       Taco Bell  7620 West Hillsborough Avenue
# 57352  hezQG50YXqdgxkhl2R9OuQ       Taco Bell  7620 West Hillsborough Avenue
# 57353  hezQG50YXqdgxkhl2R9OuQ       Taco Bell  7620 West Hillsborough Avenue
#
#                city state postal_code   latitude  longitude  stars_x  \
# 0      Ashland City    TN       37015  36.269593 -87.058943      2.0
# 1      Ashland City    TN       37015  36.269593 -87.058943      2.0
# 2      Ashland City    TN       37015  36.269593 -87.058943      2.0
# 3      Ashland City    TN       37015  36.269593 -87.058943      2.0
# 4      Ashland City    TN       37015  36.269593 -87.058943      2.0
# ...             ...   ...         ...        ...        ...      ...
# 57349         Tampa    FL       33615  27.996400 -82.565400      1.5
# 57350         Tampa    FL       33615  27.996400 -82.565400      1.5
# 57351         Tampa    FL       33615  27.996400 -82.565400      1.5
# 57352         Tampa    FL       33615  27.996400 -82.565400      1.5
# 57353         Tampa    FL       33615  27.996400 -82.565400      1.5
#
#        review_count  ...                                         categories  \
# 0                 6  ...  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 1                 6  ...  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 2                 6  ...  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 3                 6  ...  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 4                 6  ...  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# ...             ...  ...                                                ...
# 57349            30  ...  Fast Food, Restaurants, Breakfast & Brunch, Ta...
# 57350            30  ...  Fast Food, Restaurants, Breakfast & Brunch, Ta...
# 57351            30  ...  Fast Food, Restaurants, Breakfast & Brunch, Ta...
# 57352            30  ...  Fast Food, Restaurants, Breakfast & Brunch, Ta...
# 57353            30  ...  Fast Food, Restaurants, Breakfast & Brunch, Ta...
#
#                                                    hours  \
# 0      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 1      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 2      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 3      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 4      {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# ...                                                  ...
# 57349  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
# 57350  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
# 57351  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
# 57352  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
# 57353  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
#
#                     review_id                 user_id stars_y useful  funny  \
# 0      419RpsM5N8Mr-QkpuPxi5Q  gIzS3s4yZm6WiXM3TcQMPQ       4      0      0
# 1      2mD-VlkQqErngk7xwjht1g  zF10BKjK4Lz9U_8Yqw28ww       4      0      0
# 2      g4tFQ557ubgN_So9uFiSaQ  J9GBF0l6mo7DmWMT9Lo8ng       1      0      0
# 3      qhMMxTZkVq136oQuNtRQAQ  xeKMK6t7cj9c-uxIG0AGMw       1      0      0
# 4      ud3hWrqO8r4HX4W2Ngxm9A  Ot6NZYgwwZlMXmfh7ZUFsw       2      0      0
# ...                       ...                     ...     ...    ...    ...
# 57349  Xe_zWuopBfskp9IAZp-ybg  Y6SnYSEt0Hr8aYZkMPncNg       1      0      0
# 57350  RPBd0lE75qvxZVf0vkiEMg  SG7u0A5RkznmxU9wt_bbCQ       1      0      0
# 57351  Svs0dXJFDKdbc8v74VRJBw  bDFbxAlZcNKko4EnQPQdUw       1      1      0
# 57352  Z4bKui8J-ZIlb-qZ0K40Mw  m0GoKEt3l-DiH9SWmTTUQg       1      0      0
# 57353  NLVQgssKPWNoVrzw3jsgRg  aaU_NBZmNdSUu2Cs-oxxvg       1      0      1
#
#        cool                                               text  \
# 0         0  I have always liked Sonic as it is good fresh ...
# 1         0  How could I not like Sonic?  They have a Peanu...
# 2         0  The thee sundaes I ordered arrived looking kin...
# 3         0  Terrible! No customer service what so ever. We...
# 4         0  Not really sure about this location. I use to ...
# ...     ...                                                ...
# 57349     0  Don't even bother coming here and giving your ...
# 57350     0  this was the absolute WORST taco bell i've eve...
# 57351     1  Several problems at this location, the first b...
# 57352     0  They close at 2:00 am and we went at 1:35 am a...
# 57353     0  Slowest drive through in the world. Not sure w...
#
#                       date
# 0      2012-12-18 08:45:44
# 1      2013-07-08 00:59:08
# 2      2018-06-18 00:18:04
# 3      2020-06-26 19:22:36
# 4      2020-06-27 23:31:58
# ...                    ...
# 57349  2021-05-08 23:34:06
# 57350  2019-11-15 06:03:47
# 57351  2018-07-06 18:29:41
# 57352  2021-12-11 06:49:20
# 57353  2020-02-15 18:41:12
#
# [57354 rows x 22 columns]

# %%
df_open.to_csv("data_open.csv")

# %%
fastfood_list = [closed_fastfood, open_fastfood]
fastfood_df = pd.concat(fastfood_list)
fastfood_df
# Out:
#                    business_id               name  \
# 474     Dl1alpHSJE4_iB0MGKRLXw     Johnny Rockets
# 496     RsTF2skxLcp6qo9FdnA5PA          Pizza Hut
# 768     _-SSObHzljeA11HAF0lIrQ           Hardee's
# 784     ZfWVso8VlT0VN14rxVHccQ    Candida's Pizza
# 921     vLT1KtrA9bWvjFOg-0xVIg  Pieology Pizzeria
# ...                        ...                ...
# 149770  ewZeX023iPD2grGY3aL4zw             Arby's
# 149835  N9L1B3TD57wyDl7f3Awlcg                KFC
# 149963  iNKg6firpzD5u5O1Gqd0HA          Taco Bell
# 149976  8Tg3imlkSI8ugCDM4bpSeg        Chick-fil-A
# 150087  hezQG50YXqdgxkhl2R9OuQ          Taco Bell
#
#                                                   address       city state  \
# 474                             5555 St. Louis Mills Blvd  Hazelwood    MO
# 496     16 Summit Sq, Store 2B, Route 413 & Doublewood...  Langhorne    PA
# 768                               4116 W Hillsborough Ave      Tampa    FL
# 784                                       35 E Butler Ave     Ambler    PA
# 921                             7000 Hollister Ave, Ste F     Goleta    CA
# ...                                                   ...        ...   ...
# 149770                                   Pilot Travel Ctr       Troy    IL
# 149835                                     609 Naamans Rd   Claymont    DE
# 149963                           12420 St Charles Rock Rd  Bridgeton    MO
# 149976                                  2000 Belmont Blvd  Nashville    TN
# 150087                      7620 West Hillsborough Avenue      Tampa    FL
#
#        postal_code   latitude   longitude  stars  review_count  is_open  \
# 474          63042  38.786090  -90.415775    2.0             6        0
# 496          19047  40.217860  -74.926634    1.5            18        0
# 768          33614  27.995521  -82.512474    2.5            27        0
# 784          19002  40.154294  -75.222913    2.5            22        0
# 921          93117  34.430453 -119.872345    3.5           131        0
# ...            ...        ...         ...    ...           ...      ...
# 149770       62294  38.731747  -89.909024    2.0             5        1
# 149835       19703  39.817152  -75.457245    1.0            31        1
# 149963       63044  38.754822  -90.430455    1.5            20        1
# 149976       37212  36.132446  -86.795202    1.5             6        1
# 150087       33615  27.996400  -82.565400    1.5            30        1
#
#                                                attributes  \
# 474     {'RestaurantsPriceRange2': '1', 'OutdoorSeatin...
# 496     {'RestaurantsAttire': ''casual'', 'Restaurants...
# 768     {'GoodForKids': 'True', 'OutdoorSeating': 'Fal...
# 784     {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 921     {'RestaurantsAttire': ''casual'', 'Alcohol': '...
# ...                                                   ...
# 149770  {'RestaurantsReservations': 'False', 'GoodForK...
# 149835  {'RestaurantsTakeOut': 'True', 'WiFi': ''no'',...
# 149963  {'BikeParking': 'True', 'RestaurantsGoodForGro...
# 149976  {'RestaurantsReservations': 'False', 'Caters':...
# 150087  {'OutdoorSeating': 'False', 'RestaurantsTakeOu...
#
#                                                categories  \
# 474     Food, Fast Food, Sandwiches, Restaurants, Amer...
# 496     Italian, Restaurants, Fast Food, Chicken Wings...
# 768                       Restaurants, Fast Food, Burgers
# 784                         Restaurants, Pizza, Fast Food
# 921     Restaurants, Gluten-Free, Pizza, Vegan, Fast Food
# ...                                                   ...
# 149770  Burgers, Delis, Fast Food, Sandwiches, Restaur...
# 149835  Chicken Shop, Chicken Wings, Fast Food, Restau...
# 149963  Fast Food, Breakfast & Brunch, Restaurants, Ta...
# 149976  Caterers, Chicken Shop, Event Planning & Servi...
# 150087  Fast Food, Restaurants, Breakfast & Brunch, Ta...
#
#                                                     hours
# 474     {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 496     {'Monday': '10:30-23:0', 'Tuesday': '10:30-23:...
# 768     {'Monday': '5:0-21:0', 'Tuesday': '5:0-21:0', ...
# 784     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 921     {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...
# ...                                                   ...
# 149770                                               None
# 149835  {'Monday': '10:30-23:0', 'Tuesday': '10:30-23:...
# 149963  {'Monday': '8:0-2:0', 'Tuesday': '8:0-2:0', 'W...
# 149976  {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:0', ...
# 150087  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
#
# [3148 rows x 14 columns]
